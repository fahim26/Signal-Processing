# %%
"""
Author : MD Fahimul Islam
Reg No:  2017331026

"""


import numpy

def convlve(x_n,h_n):
  y_n = []
  for n in range(0,len(x_n)+len(h_n)-1):
    sum = 0
    for k in range(0,len(x_n)):
      if ((n-k) >= 0 and (n-k) < len(h_n)):
        sum += x_n[k]*h_n[n-k]
    y_n.append(sum)
  return y_n

x_n = [1,2,3,1]
h_n = [1,2,1,-1]

print("SIGNAL 1: ",x_n)
print("SIGNAL 2: ",h_n)

out = convlve(x_n,h_n)
print("OUTPUT OF LINEAR CONVOLUTION OF MY FUNCTION: ",out)

plt.figure(figsize = (12, 6))
plt.stem(x_n)
plt.xlabel("SIGNAL 1 (x_n)")
plt.xlim(-2, len(x_n)+len(h_n)+1)

plt.figure(figsize = (12, 6))
plt.stem(h_n)
plt.xlabel("SIGNAL 2 (h_n)")
plt.xlim(-2, len(x_n)+len(h_n)+1)


plt.figure(figsize = (12, 6))
plt.stem(out)
plt.xlabel("LINEAR CONVOLUTION SIGNAL")
plt.xlim(-2, len(x_n)+len(h_n)+1)

out = numpy.convolve(x_n,h_n)   
print("OUTPUT OF LINEAR CONVOLUTION OF PYTHON FUNCTION: ",out)
print("")
print("")
# Out:
# SIGNAL 1:  [1, 2, 3, 1]
# SIGNAL 2:  [1, 2, 1, -1]
# OUTPUT OF LINEAR CONVOLUTION OF MY FUNCTION:  [1, 4, 8, 8, 3, -2, -1]
# OUTPUT OF LINEAR CONVOLUTION OF PYTHON FUNCTION:  [ 1  4  8  8  3 -2 -1]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...
